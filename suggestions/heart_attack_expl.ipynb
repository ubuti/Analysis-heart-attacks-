# %% [markdown]
# # **Heart Attack analysis**

# %% [markdown]
# In this notebook we explore a dataset about heart attacks and look at factors with regard to their occurences.
# Our main focus lies on the questions whether
# - There is no significant difference between the different factors of a heart attack depending on the gender
# - The chance of having a heart attack correlates with the type of chest pain
# - CAA has a direct influence on the resting blood pressure, maximal heart rate and exercise induced angina
# - There are more or less relevant factors that may predict a heart attack
#
# The dataset was downloaded here:
# https://www.kaggle.com/rashikrahmanpritom/heart-attack-analysis-prediction-dataset

# %% [markdown]
# # Importing Data and Modules

# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4dd8edb4-9d1f-418c-b965-0afc93924775" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4dd8edb4-9d1f-418c-b965-0afc93924775">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving heart.csv to heart.csv

# %%
import io

df = pd.read_csv(io.BytesIO(uploaded['heart.csv']))
# Dataset is now stored in a Pandas Dataframe

# %% [markdown]
# # Explorig data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.isnull().values.any()
#No Nan Values
# Out:
# False

# %%
df.rename(columns={'cp':'chest_pain','trtbps': 'resting_BP','chol':'cholesterol', 'fbs':'fasting_BS', 'restecg':'resting_ECG', 'thalachh': 'max_heart_rate', 'slp': 'ST_slope', 'output':'HA_pred' },inplace=True)

# %%
#0 Age 
#1 Sex 
#2 Chest pain 1-4
#3 resting_bp
#4 cholesterol
#5 fasting_bs 
#6 resting_ecg_result  
#7 max_heart_rate
#8 exang 
#9 oldpeak (bit tricky)
#10 st_slope 
#11 caa // include description somewhere corona artery anomalities
#12 thal // thalassemia
#13 HA_pred // Heart attack prediction

df.columns
# Out:
# Index(['age', 'sex', 'chest_pain', 'resting_BP', 'cholesterol', 'fasting_BS',
#        'resting_ECG', 'max_heart_rate', 'exng', 'oldpeak', 'ST_slope', 'caa',
#        'thall', 'HA_pred'],
#       dtype='object')

# %% [markdown]
# # *Explain variable values*

# %% [markdown]
# #      Variables
#
#  age
#  * age of patient
#
# ---
#
#  sex
#
# *    conditions:
#
#  * 0: female
#
#  * 1: male
#
# ---
#  chest_pain (chest pain type)
#
# *  conditions:
#
#  * 0: typical angina
#
#  *  1: atypical angina
#
#  * 2: non-anginal pain
#
#  * 3: asymptomatic
#
#
#
# ---
#
#  resting_BP (resting blood pressure)
# *    in mm Hg
# *   measured on admission to hospital
# *    normally: 120/80
#
#
# ---
#
#  cholesterol
# *    mg/dl
# *    200-239 is considered borderline high
# *    value >240 is too high
#
# ---
#
#  fasting_BS (fasting blood sugar)
# *    120 mg/dl
# *    conditions:
# 	*  1: > 120 mg/dl
# 	*  0: <= 120 mg/dl
# *    normal: ~100
#
# ---
#
#  resting_ECG (resting electrocardiographic results)
# *    conditions:
# 	*  0: normal
# 	*  1: ST-T
# 	*  2: hypertrophy
#
# ---
#
#  max_heart_rate (maximum heart rate achieved)
# *    normal: 72
#
# ---
#
#  exng (exercise induced angina)
# *    conditions:
# 	*  1: true
# 	*  0: false
#
# ---
#
#  oldpeak:
# *    ST depression induced by exercise relative to rest
# ---
#
#  ST_slope:
# *    slope of peak exercise ST segment
# ST_slope:
# *    slope of peak exercise ST segment
# *    conditions:
# 	*  0: upsloping
# 	*  1: flat
# 	*  2: downsloping
#
# ---
#
#  caa (number of major vessels (index or nr?)):
# *    range:
# 	*    0 - 4
#
# ---
#
#  thall (thallamaesia)
# *    conditions:
# 	*  1: normal
# 	*  2: fixed defect
# 	*  3: reversable defect
# ---
#
#  HA_pred (chance of heart attack)
# *    conditions:
# 	*  0: less chance of heart attack
# 	*  1: more chance of heart attack

# %% [markdown]
# # *Do some stat methods here*

# %%
# Calc mean, sd, median for age, resting_BP, fasting_BS, max_HR

# %%
#Calculate the number of female and male subjects

# TO suppress warnings use this:
import warnings
warnings.filterwarnings('ignore')

#Calculate the mean of the cholesteral grouped by sex 
df_1 = df.groupby('sex', as_index=False)['cholesterol','age', 'resting_BP','max_heart_rate'].mean().round(2)
#Calculate the median of the cholesteral grouped by sex 
df_2 = df.groupby('sex', as_index=False)['cholesterol','age', 'resting_BP','max_heart_rate'].median().round(2)

# Tidy format 
df_2.rename(index={0:'Male',1:'Female'},inplace=True)
df_1.rename(index={0:'Male',1:'Female'},inplace=True)

display(df_1)
display(df_2)
;
# Out:
#         sex  cholesterol    age  resting_BP  max_heart_rate
# Male      0       261.30  55.68      133.08          151.12
# Female    1       239.29  53.76      130.95          148.96
#         sex  cholesterol  age  resting_BP  max_heart_rate
# Male      0          253   57         131             157
# Female    1          235   54         130             151
# ''

# %% [markdown]
# # *Data visualization*

# %%
import matplotlib.pyplot as plt

# Vars: sex, chest_pain, fasting_BS, resting_ECG, exng, ST_slope, caa, thall,HA_pred 

fig, plot = plt.subplots(3,3, figsize = (11,9))

fig.suptitle('Value distribution of discrete variables', fontsize = 22, y = 1.04)


plot[0,0] = sns.countplot(data = df,
                        x = 'sex',
                        ax = plot[0,0])
plot[0,0].set_title('Sex',fontsize = 14)
plot[0,0].set_xticklabels(['Female','Male'])
plot[0,0].set_xlabel('')

plot[0,1] = sns.countplot(data = df,
                      x = 'chest_pain',
                      ax = plot[0,1])
# (1 = typical angina; 2 = atypical angina; 3 = non-anginal pain; 4 = asymptomatic)
#plot[0,1].set_xticklabels(['angina','atypical angina','non_anginal','asymptomatic'])
plot[0,1].set_title('Chest pain',fontsize = 14)
plot[0,1].set_xlabel('')

plot[0,2] = sns.countplot(data = df,
                        x = 'fasting_BS',
                        ax = plot[0,2])
plot[0,2].set_title('Blood sugar > 120 mg/dl',fontsize = 14)
plot[0,2].set_xticklabels(['False','True'])
plot[0,2].set_xlabel('')

plot[1,0] = sns.countplot(data = df,
                       x = 'resting_ECG',
                       ax = plot[1,0])
plot[1,0].set_title('Heart Rythmn/resting ECG',fontsize = 14)
#0 = normal; 1 = having ST-T; 2 = hypertrophy
plot[1,0].set_xticklabels(['normal','ST-T','hypertrophy'])
plot[1,0].set_xlabel('')


plot[1,1] = sns.countplot(data = df,
                       x = 'exng',
                       ax = plot[1,1])
plot[1,1].set_title('Exercise induced angina ',fontsize = 14)
plot[1,1].set_xticklabels(['False','True'])

plot[1,2] = sns.countplot(data = df,
                       x = 'ST_slope',
                       ax = plot[1,2])
plot[1,2].set_title('ST-slope',fontsize = 14)
plot[1,2].set_xticklabels(['up','flat','down'])
plot[1,2].set_xlabel('')

plot[2,0] = sns.countplot(data = df,
                      x = 'caa',
                      ax = plot[2,0],
                      )
plot[2,0].set_xlabel('number blocked vessels (caa)')
plot[2,0].set_title('Corona artery anomalities ',fontsize = 14)

plot[2,1] = sns.countplot(data = df,
                       x = 'thall',
                       ax = plot[2,1])
plot[2,1].set_title('Thalassemia',fontsize = 14)
plot[2,1].set_xlabel('') # Missing description

plot[2,2] = sns.countplot(data = df,
                          x = 'HA_pred',
                          ax = plot[2,2])
plot[2,2].set_title('Heart attack risk',fontsize = 14);
plot[2,2].set_xticklabels(['Negative','Positive'])
plot[2,2].set_xlabel('')


fig.tight_layout()

# Include some comments

# %%
import matplotlib.pyplot as plt

fig, plot = plt.subplots(1,5, figsize = (24,8))

fig.suptitle('Value distribution of continuous variables',fontsize = 25,y=1.08)
fig.tight_layout()

plot[0] = sns.histplot(data = df,
                        x = 'age',
                        ax = plot[0],
                        bins = 'auto',
                       )
plot[0].set_title('Age [years]',fontsize = 20)

plot[1] = sns.histplot(data = df,
                       x = 'resting_BP',
                       bins = 'auto',
                       ax = plot[1])
plot[1].set_title('Resting blood pressure [in mm Hg]',fontsize = 20)

plot[2] = sns.histplot(data = df,
                      x = 'cholesterol',
                      ax = plot[2],
                      bins = 'auto'
                      )
plot[2].set_title(' Cholesterol [mg/dl]',fontsize = 20)

plot[3] = sns.histplot(data=df,
                       x = 'max_heart_rate',
                       bins = 'auto',
                       kde = False,
                       ax = plot[3])
plot[3].set_title(' Max heart rate [beats/minute]',fontsize = 20)

plot[4] = sns.histplot(data = df,
                       x = 'oldpeak',
                       bins = 'auto',
                       ax = plot[4],
                       kde = False,
                       )
plot[4].set_title(' Oldpeak [?]',fontsize = 20)
plot[0].set_xlabel('')
plot[1].set_xlabel('')
plot[2].set_xlabel('')
plot[3].set_xlabel('')
plot[4].set_xlabel('')
# Out:
# Text(0.5, 51.0, '')

# %% [markdown]
# Here is yet another visulization of the varibale *age*

# %%
 fig, plot = plt.subplots(1,2,figsize=(12,8))
 
 sns.kdeplot(data=df,x='age',shade=True,shade_lowest=True,cumulative=False,ax=plot[0])
 sns.kdeplot(data=df,x='age',shade=True,shade_lowest=True,cumulative=True,color='orange',ax=plot[1])

 plot[0].set(title='Density distribution')
 plot[1].set(title='Density distribution accumulated')
 
 warnings.warn('ignore')

# %% [markdown]
# # Data Cleaning

# %%
# Make outlier detection and deletion
from scipy import stats
import numpy as np

df_cleaned = df[(np.abs(stats.zscore(df['cholesterol'])) < 3)]
df_cleaned = df_cleaned[(np.abs(stats.zscore(df_cleaned['max_heart_rate'])) < 3)] 
df_cleaned = df_cleaned[(np.abs(stats.zscore(df_cleaned['oldpeak'])) < 3)]
df_cleaned = df_cleaned[(np.abs(stats.zscore(df_cleaned['resting_BP'])) < 3)]

# %%
# Verify zscore; Delete ? Yes.
fig, plot = plt.subplots(1,5, figsize = (24,8))

fig.suptitle('Value distribution of continuous variables',fontsize = 25,y=1.08)
fig.tight_layout()

plot[0] = sns.histplot(data = df_cleaned,
                        x = 'age',
                        ax = plot[0],
                        bins = 'auto',
                       )
plot[0].set_title('Age [years]',fontsize = 20)

plot[1] = sns.histplot(data = df_cleaned,
                       x = 'resting_BP',
                       bins = 'auto',
                       ax = plot[1])
plot[1].set_title('Resting blood pressure [in mm Hg]',fontsize = 20)

plot[2] = sns.histplot(data = df_cleaned,
                      x = 'cholesterol',
                      ax = plot[2],
                      bins = 'auto'
                      )
plot[2].set_title(' Cholesterol [mg/dl]',fontsize = 20)

plot[3] = sns.histplot(data=df_cleaned,
                       x = 'max_heart_rate',
                       bins = 'auto',
                       kde = False,
                       ax = plot[3])
plot[3].set_title(' Max heart rate [beats/minute]',fontsize = 20)

plot[4] = sns.histplot(data = df_cleaned,
                       x = 'oldpeak',
                       bins = 'auto',
                       ax = plot[4],
                       kde = False,
                       )
plot[4].set_title(' Oldpeak [?]',fontsize = 20)
plot[0].set_xlabel('')
plot[1].set_xlabel('')
plot[2].set_xlabel('')
plot[3].set_xlabel('')
plot[4].set_xlabel('')
;

# %%
import matplotlib.pyplot as plt

#Delete at the end.

# Vars: sex, chest_pain, fasting_BS, resting_ECG, exng, ST_slope, caa, thall,HA_pred 

fig, plot = plt.subplots(3,3, figsize = (11,9))

fig.suptitle('Value distribution of discrete variables', fontsize = 22, y = 1.04)


plot[0,0] = sns.countplot(data = df_cleaned,
                        x = 'sex',
                        ax = plot[0,0])
plot[0,0].set_title('Sex',fontsize = 14)
plot[0,0].set_xticklabels(['Female','Male'])
plot[0,0].set_xlabel('')

plot[0,1] = sns.countplot(data = df_cleaned,
                      x = 'chest_pain',
                      ax = plot[0,1])
# (1 = typical angina; 2 = atypical angina; 3 = non-anginal pain; 4 = asymptomatic)
#plot[0,1].set_xticklabels(['angina','atypical angina','non_anginal','asymptomatic'])
plot[0,1].set_title('Chest pain',fontsize = 14)
plot[0,1].set_xlabel('')

plot[0,2] = sns.countplot(data = df_cleaned,
                        x = 'fasting_BS',
                        ax = plot[0,2])
plot[0,2].set_title('Blood sugar > 120 mg/dl',fontsize = 14)
plot[0,2].set_xticklabels(['False','True'])
plot[0,2].set_xlabel('')

plot[1,0] = sns.countplot(data = df_cleaned,
                       x = 'resting_ECG',
                       ax = plot[1,0])
plot[1,0].set_title('Heart Rythmn/resting ECG',fontsize = 14)
#0 = normal; 1 = having ST-T; 2 = hypertrophy
plot[1,0].set_xticklabels(['normal','ST-T','hypertrophy'])
plot[1,0].set_xlabel('')


plot[1,1] = sns.countplot(data = df_cleaned,
                       x = 'exng',
                       ax = plot[1,1])
plot[1,1].set_title('Exercise induced angina ',fontsize = 14)
plot[1,1].set_xticklabels(['False','True'])

plot[1,2] = sns.countplot(data = df_cleaned,
                       x = 'ST_slope',
                       ax = plot[1,2])
plot[1,2].set_title('ST-slope',fontsize = 14)
plot[1,2].set_xticklabels(['up','flat','down'])
plot[1,2].set_xlabel('')

plot[2,0] = sns.countplot(data = df_cleaned,
                      x = 'caa',
                      ax = plot[2,0],
                      )
plot[2,0].set_xlabel('number blocked vessels (caa)')
plot[2,0].set_title('Corona artery anomalities ',fontsize = 14)

plot[2,1] = sns.countplot(data = df_cleaned,
                       x = 'thall',
                       ax = plot[2,1])
plot[2,1].set_title('Thalassemia',fontsize = 14)
plot[2,1].set_xlabel('') # Missing description

plot[2,2] = sns.countplot(data = df_cleaned,
                          x = 'HA_pred',
                          ax = plot[2,2])
plot[2,2].set_title('Heart attack risk',fontsize = 14);
plot[2,2].set_xticklabels(['Negative','Positive'])
plot[2,2].set_xlabel('')


fig.tight_layout()

# Include some comments

# %% [markdown]
# # Hypothesis testing

# %% [markdown]
# Examine the distribution among *age* of the various types of *resting_ECG* data (electroenzephalogram)

# %%
df_filtered = df_cleaned.query('age >= 50 and age <= 70')

fig, plot = plt.subplots(figsize=(12,8))

plot = sns.countplot(data=df_filtered,
              x='age',
              hue='resting_ECG',
              dodge=True,
              )
plot.legend(labels =['normal', 'ST-T','hypertrophy']);

# %%
sns.set_theme(palette='Dark2',font_scale=1.6) # Dark2_r

sns.relplot(data = df_cleaned,
            col = 'chest_pain',
            hue = 'HA_pred',
            #style = 'HA_pred',
            x = 'resting_BP',
            y = 'max_heart_rate',
            #size = 'sex'
            ) 

sns.lmplot(data= df_cleaned,
           x = 'resting_BP',
           y = 'max_heart_rate',
           col = 'chest_pain',
           hue = 'resting_ECG',
           scatter=False
           )
;
# Out:
# ''

# %%
sns.set_theme(palette='Dark2',font_scale=1.6)

sns.relplot(data = df_cleaned,
            col = 'chest_pain',
            hue = 'HA_pred',
            #style = 'HA_pred',
            y = 'cholesterol',
            x = 'age',
            
            ) 

sns.lmplot(data= df_cleaned,
           x = 'age',
           y = 'cholesterol',
           col = 'chest_pain',
           hue = 'HA_pred',
           scatter=False
           );

# %%
# Split Df into groups by feature value

def split(df_cleaned, group):
     gb = df_cleaned.groupby(group)
     return [gb.get_group(x) for x in gb.groups]

splittable = split(df_cleaned,'chest_pain')

# %%
import numpy as np

# Count feature occurence of condition/value
def count_counts(df, condition):
  return df.query(condition).shape[0]

neg = []
pos = []
for s in splittable:
  neg.append((count_counts(s, condition='HA_pred == 0')))
  pos.append((count_counts(s, condition='HA_pred == 1')))

frame = pd.DataFrame(data=(neg,pos)).transpose()
frame[2] = frame[0] + frame[1]
frame.rename(axis=1,mapper={0:'neg',1:'pos',2:'total'},inplace=True)
frame.rename(index={0:'cp-1',1:'cp-2',2:'cp-3',3:'cp-4'},inplace=True)
frame['%'] = round(frame['pos']/frame['total'],2)
frame
# Out:
#       neg  pos  total     %
# cp-1   98   39    137  0.28
# cp-2    8   41     49  0.84
# cp-3   18   67     85  0.79
# cp-4    7   16     23  0.70

# %%
# Get conditional probability on column chest_pain

# Start by calculation P(chest_pain)
# Sample size 303
joint_prob_pos = frame['pos']/303
joint_prob_neg = 1-joint_prob_pos
start_prob = [round(x/303,2) for x in frame['total']]

# Make table with cond. probs for chest_pain types
results = []
for index, value in enumerate(start_prob):
  #print('Probability of an heart attack given the types of chest pain: chest pain type {:} prob = {:}'.format(index,round(joint_prob_pos[index]/value,3)))
  results.append(round(joint_prob_pos[index]/value,2))

# Put into table form 
data = pd.DataFrame(data=(results,start_prob,joint_prob_pos,joint_prob_neg)).T
data.rename(inplace=True,columns={0:'P(H|CP)',1:'P(CP)',2:'P(H,CP)',3:'P(-H,CP)'},index={0:'type-1',1:'type-2',2:'type-3',3:'type-4'})

data
# Out:
#         P(H|CP)  P(CP)   P(H,CP)  P(-H,CP)
# type-1     0.29   0.45  0.128713  0.871287
# type-2     0.85   0.16  0.135314  0.864686
# type-3     0.79   0.28  0.221122  0.778878
# type-4     0.66   0.08  0.052805  0.947195

# %% [markdown]
# **Observation**:
#
# The conditonal probability table tells us the likelihood of getting a heart attack given a type of chest pain.
# A short reminder types of chest pain:
#
#     0: typical angina
#     1: atypical angina
#     2: non-anginal pain
#     3: asymptomatic
#
# Thus, a typical anginal pain:0 shows the lowest cond.probability while having the highest marginal probability. The highest cond. prob. of suffering a heart attack goes along with type 2, then 3, then 4.

# %%
sns.set_theme(font_scale=1.5,palette= 'gist_rainbow_r')

sns.relplot(data = df_cleaned, 
            x ='resting_BP',
            y = 'cholesterol', 
            col= 'exng',
            #hue= 'chest_pain',
            style='chest_pain')

sns.lmplot(data= df_cleaned,
           x = 'resting_BP',
           y = 'cholesterol',
           col = 'exng',
           hue = 'sex',
           );

# %%
splittable = split(df_cleaned, 'exng')
groups= []
for group in splittable:
  groups.append(count_counts(group,'chest_pain == 0'))
  groups.append(count_counts(group,'chest_pain == 1'))
  groups.append(count_counts(group,'chest_pain == 2'))
  groups.append(count_counts(group,'chest_pain == 3'))


groups.insert(4,sum([groups[0],groups[1],groups[2],groups[3]]))
groups.insert(9,sum([groups[5],groups[6],groups[7],groups[8]]))
groups

# Create DataFrame 
frame = pd.DataFrame(data=(groups[0:5],groups[5::]))
frame.rename(axis=1, mapper = {0:'cp1',1:'cp2',2:'cp3',3:'cp4',4:'total'},inplace=True)
frame
# Out:
#    cp1  cp2  cp3  cp4  total
# 0   60   45   74   19    198
# 1   77    4   11    4     96

# %%
sns.displot(data = df_cleaned, 
            x = 'age',
            y = 'max_heart_rate',
            bins = 'auto',
            rug = True,
            rug_kws = {'color':'orange'},
            height = 8,
            kind = 'hist' # kde, ecdf, default:hist
            );

# %%
sns.set_theme(palette='hot', font_scale = 1.2,font = 'sans')

sns.set_style("ticks", {"xtick.major.size": 12, "ytick.major.size": 12})

sns.catplot(data =df_cleaned,
            x = 'caa',
            y = 'max_heart_rate',
            hue = 'HA_pred',
            height = 7);

# %%
df_split = split(df,'caa')
caa_data = []
for i,v in enumerate(df_split):
  caa_data.append(count_counts(df_split[i],'HA_pred == 0'))
  caa_data.append(count_counts(df_split[i],'HA_pred == 1'))

HA_neg = caa_data[0::2]
HA_pos = caa_data[1::2]
HA_neg.append(sum(HA_neg))
HA_pos.append(sum(HA_pos))
frame = pd.DataFrame(data=(HA_neg,HA_pos))
frame.rename(axis=1,inplace=True,mapper={0:'type0',1:'type1',2:'type2',3:'type3',4:'type4',5:'total'})
frame.rename(axis=0,inplace=True,mapper={0:'ha_neg',1:'ha_pos'})
frame
# Out:
#         type0  type1  type2  type3  type4  total
# ha_neg     45     44     31     17      1    138
# ha_pos    130     21      7      3      4    165

# %%
HA_neg_new = [round(x/303,3) for x in HA_neg]
HA_pos_new = [round(x/303,3) for x in HA_pos]
frame = pd.DataFrame(data=(HA_neg_new,HA_pos_new))
frame.rename(axis=1,inplace=True,mapper={0:'type0',1:'type1',2:'type2',3:'type3',4:'type4',5:'total'})
frame.rename(axis=0,inplace=True,mapper={0:'ha_neg',1:'ha_pos'})
frame['total']=[138,165]
frame
# Out:
#         type0  type1  type2  type3  type4  total
# ha_neg  0.149  0.145  0.102  0.056  0.003    138
# ha_pos  0.429  0.069  0.023  0.010  0.013    165

# %%
sns.set_theme(font_scale = 1.2,font = 's')

sns.set_style("ticks", {"xtick.major.size": 12, "ytick.major.size": 12})

sns.jointplot(data=df,
              x = 'age',
              y = 'resting_BP',
              height = 7,
              hue = 'resting_ECG',
              )

# %%
fix,plot = plt.subplots(figsize=(12,7))


sns.lineplot(data=df,
             x = 'cholesterol',
             y = 'age',
             palette = 'tab10',
             linewidth = 2.5,
             ax = plot,
             ci = 5,
             )

sns.set_theme(style='whitegrid')


plot.axis([100,450,35,70])



plot = sns.lmplot(data=df,
             x = 'cholesterol',
             y = 'age',
             #palette = 'tab12',
             hue = 'sex',
             markers = ['o','v'],
             #scatter = False
           )

# %%
sns.pairplot(data=df,
             hue='sex')

# %% [markdown]
# # Discussion
#
# Research hypothesis question in respect to something plotted

# %% [markdown]
# ###**Chest pain & heart attack correlation**

# %% [markdown]
# Let's explore the relevance of the types of chest pain in respective to their heart attack causation.
# Observe different ways of analysis.

# %%
# To visualize this .. 

sns.set_theme(palette='Dark2',font_scale=1.6)

sns.relplot(data = df,
            col = 'chest_pain',
            hue = 'HA_pred',
            #style = 'HA_pred',
            y = 'cholesterol',
            x = 'age',
            
            ) ;

# %% [markdown]
# ######**Observation:**
#
# We see a clear dominance for non-threatening chest pain in plot 1 ~ chest pain type 1.
# The difference among the subplots consists quantitatively in the number of data points and their colour.
# Thus, it looks like there is low evidence to say that cholesterol plays a big role regarding the HA_pred.
# However the type of chest pain is greater of a criterium.

# %%
# One more plot, but something big

# Try linear regression here
from sklearn.linear_model import LinearRegression
import itertools

# %%
df.tail()
# Out:
#      age  sex  chest_pain  resting_BP  ...  ST_slope  caa  thall  HA_pred
# 298   57    0           0         140  ...         1    0      3        0
# 299   45    1           3         110  ...         1    0      3        0
# 300   68    1           0         144  ...         1    2      3        0
# 301   57    1           0         130  ...         1    1      3        0
# 302   57    0           1         130  ...         1    1      2        0
#
# [5 rows x 14 columns]

# %% [markdown]
# **Run a regression model - search for factor cominations with highest fit**

# %%
# Use independent variables age, sex, chest_pain, cholesterol, resting_BP, max_heart_rate, resting_ECG,caa; exclude thall, ST-slope, oldepeak, exng
# Model lr
#model = LinearRegression(n_jobs = -1).fit(df_numpy_X,df_numpy_Y)

# Vars of interest
variables = ['age','sex','chest_pain','resting_BP','resting_ECG','max_heart_rate','caa','cholesterol','fasting_BS']

# def function for automized lr
def auto_lr(names:list):
  # Shape and feed input
  df_numpy_X = df[[*names]].to_numpy()
  df_numpy_Y = df['HA_pred'].to_numpy()
  model = LinearRegression(n_jobs = -1).fit(df_numpy_X,df_numpy_Y)
  # coefficient of determination R^2
  R_SQ = model.score(df_numpy_X, df_numpy_Y)
  #print(f'Coefficient of determination: {R_SQ}')
  print(f'intercept: {model.intercept_}')
  print(f'slope: {model.coef_}')
  print(f'model-params: {[*names]}')
  return R_SQ, model
  
auto_lr(['age','chest_pain'])
# Out:
# intercept: 0.9351225329426647
# slope: [-0.01079737  0.2031499 ]
# model-params: ['age', 'chest_pain']
# (0.22664394001254928,
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=-1, normalize=False))

# %%
# Func to maximize auto_lr

# Vars of interest
variables = ['age','sex','chest_pain','resting_BP','resting_ECG','max_heart_rate','caa','cholesterol','fasting_BS']

def max_auto_lr(variables):
  # For plotting keep track of R-val, number of steps
  R_Values = []
  R_Step = []
  i = 0
  search_len = len(variables)
  #Start with base combination of all vars
  iterated = itertools.combinations(variables,search_len)

  for comb in iterated: 
    R_SQ ,model = auto_lr(comb)
  
  Final_comb = comb
  Model_Coef = model.coef_
  R_Values.append(R_SQ)
  R_Step.append(i)
  i +=1

  # As long as there is a combination of variables with at least one var
  while True:


    search_len -= 1
    if search_len == 0:
      # Else break here;
      break
    # Get other combs
    iterated = itertools.combinations(variables, search_len)
    for comb in iterated:
      R_SQ_2, model = auto_lr(comb)
      R_Values.append(R_SQ_2)
      R_Step.append(i)
      i += 1 

      if R_SQ_2 > R_SQ:
        R_SQ = R_SQ_2
        Final_comb = comb
        Model_Coef = model.coef_
  
  return R_SQ, Final_comb, Model_Coef, R_Values, R_Step
    
VAL, COMB, COEF, R_Values, R_Step = max_auto_lr(variables)

# Show any of them:  
#VAL
#COMB
#COEF
#R_Step
#R_Values
# Out:
# intercept: 0.4257432877659193
# slope: [-0.00041457 -0.26295465  0.14421939 -0.00351511  0.05491344  0.00569289
#  -0.11311381 -0.00064115  0.02476755]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'caa', 'cholesterol', 'fasting_BS']
# intercept: 0.4143609099169868
# slope: [-0.00035032 -0.2621094   0.1451712  -0.00344441  0.05394583  0.00570127
#  -0.11206062 -0.00064419]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.3251354068480136
# slope: [-0.0011178  -0.24963044  0.14717903 -0.0036147   0.06332329  0.005547
#  -0.11414461  0.02635134]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.49104915647456604
# slope: [-0.00323551 -0.29556779  0.16067219 -0.00368294  0.05753264  0.00606014
#  -0.00070977 -0.01176745]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.4775430332467256
# slope: [-0.00616075 -0.2754859   0.17675295 -0.00319587  0.05447598 -0.12122105
#  -0.00042677  0.03119201]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.5054794944244779
# slope: [-0.00061135 -0.26859533  0.14511697 -0.00363744  0.00569007 -0.11348533
#  -0.00072056  0.02000626]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'max_heart_rate', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.09413358298423852
# slope: [-0.00216049 -0.25903904  0.14134605  0.06303277  0.00555674 -0.11469394
#  -0.00070356  0.00167828]
# model-params: ['age', 'sex', 'chest_pain', 'resting_ECG', 'max_heart_rate', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.22202092673485196
# slope: [ 0.0009795  -0.27203602 -0.00311451  0.06321919  0.00762729 -0.13470921
#  -0.00089974  0.0681064 ]
# model-params: ['age', 'sex', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.03156220965602774
# slope: [ 0.00129598  0.14779169 -0.00330036  0.07544546  0.00598598 -0.12995261
#  -0.00018321  0.00962807]
# model-params: ['age', 'chest_pain', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.4025960600900386
# slope: [-0.26217792  0.14397038 -0.00355859  0.05523869  0.00575391 -0.11377518
#  -0.00065212  0.02424498]
# model-params: ['sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.31251395991948483
# slope: [-0.00105296 -0.24866365  0.14820695 -0.00353996  0.06233591  0.00555519
#  -0.11302894]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'caa']
# <class 'numpy.float64'>
# intercept: 0.4968253286873391
# slope: [-0.00327911 -0.29612126  0.16028747 -0.00371775  0.05801052  0.00605775
#  -0.00070861]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.38022485507736503
# slope: [-0.00404324 -0.28113254  0.16411792 -0.003795    0.06687806  0.00590219
#  -0.01038138]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.4651554819056047
# slope: [-0.00609046 -0.27444425  0.17801252 -0.00310621  0.0532561  -0.11990923
#  -0.0004302 ]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 1.3918994912892573
# slope: [-0.00653402 -0.26632458  0.17818027 -0.00326823  0.06012978 -0.12177364
#   0.03214481]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.6209086929656076
# slope: [-0.00959702 -0.31146925  0.19672654 -0.0033544   0.05726557 -0.00048576
#  -0.00769723]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.49511523481531833
# slope: [-0.00055646 -0.26782968  0.1458756  -0.00357839  0.00569691 -0.11262641
#  -0.00072189]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'max_heart_rate', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.40421430779125733
# slope: [-0.00145147 -0.25432101  0.14866495 -0.00377299  0.00552245 -0.11473138
#   0.02098528]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'max_heart_rate', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.5748263878913455
# slope: [-0.00345141 -0.30159068  0.16166936 -0.00381171  0.00605846 -0.00079321
#  -0.01688237]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'max_heart_rate', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.5561291431788953
# slope: [-0.00635314 -0.28107552  0.17762745 -0.00331738 -0.12158565 -0.00050565
#   0.02646548]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.09380812967354385
# slope: [-0.00215363 -0.25898611  0.14141577  0.06295467  0.00555751 -0.11461901
#  -0.00070369]
# model-params: ['age', 'sex', 'chest_pain', 'resting_ECG', 'max_heart_rate', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: -0.026912648664128347
# slope: [-0.00298875 -0.2442552   0.14451321  0.07253998  0.00539196 -0.11587748
#   0.00270119]
# model-params: ['age', 'sex', 'chest_pain', 'resting_ECG', 'max_heart_rate', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.144330445340224
# slope: [-0.00510733 -0.29194013  0.15790062  0.06608369  0.00592278 -0.00077621
#  -0.03651042]
# model-params: ['age', 'sex', 'chest_pain', 'resting_ECG', 'max_heart_rate', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.152473812120222
# slope: [-0.00762635 -0.27164508  0.17342595  0.06188353 -0.12248414 -0.00048831
#   0.01001398]
# model-params: ['age', 'sex', 'chest_pain', 'resting_ECG', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.17281736944273512
# slope: [-0.00245764 -0.26538999  0.1422663   0.00554803 -0.11518605 -0.00079769
#  -0.00474239]
# model-params: ['age', 'sex', 'chest_pain', 'max_heart_rate', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.18661533115168932
# slope: [ 0.00118384 -0.2698513  -0.00291048  0.06067983  0.00768615 -0.1321758
#  -0.00091294]
# model-params: ['age', 'sex', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.07374135060584264
# slope: [ 2.48892026e-05 -2.53445514e-01 -3.24380890e-03  7.53606104e-02
#   7.47702829e-03 -1.36794951e-01  7.16060358e-02]
# model-params: ['age', 'sex', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.27323209891373995
# slope: [-0.00226119 -0.31300163 -0.0032632   0.06756146  0.00834307 -0.00101919
#   0.02964667]
# model-params: ['age', 'sex', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.6815169510298282
# slope: [-0.00690199 -0.29319164 -0.00252017  0.06530312 -0.15354171 -0.00067332
#   0.09161433]
# model-params: ['age', 'sex', 'resting_BP', 'resting_ECG', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.31244279722203616
# slope: [ 0.00076274 -0.27860111 -0.0032526   0.00763793 -0.13529221 -0.0009931
#   0.0629306 ]
# model-params: ['age', 'sex', 'resting_BP', 'max_heart_rate', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.06886141233290011
# slope: [-0.00059564 -0.26839807  0.07028263  0.00747216 -0.13573036 -0.00095059
#   0.04683512]
# model-params: ['age', 'sex', 'resting_ECG', 'max_heart_rate', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.03542310908907542
# slope: [ 0.00131887  0.14815795 -0.0032731   0.07504287  0.00598888 -0.1295213
#  -0.00018496]
# model-params: ['age', 'chest_pain', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: -0.0545201297481166
# slope: [ 0.00106179  0.14861549 -0.00333312  0.07763034  0.00593832 -0.13000525
#   0.01032506]
# model-params: ['age', 'chest_pain', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.021509880188859798
# slope: [-0.00175754  0.1675679  -0.00346564  0.08149179  0.00645839 -0.00019704
#  -0.03533309]
# model-params: ['age', 'chest_pain', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.0541373897400614
# slope: [-4.67496747e-03  1.82263808e-01 -2.95308141e-03  7.60157208e-02
#  -1.39344066e-01  6.57663934e-05  1.56394090e-02]
# model-params: ['age', 'chest_pain', 'resting_BP', 'resting_ECG', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.06528641994662565
# slope: [ 0.00107427  0.14914098 -0.00346341  0.00599079 -0.13096745 -0.00027958
#   0.00258385]
# model-params: ['age', 'chest_pain', 'resting_BP', 'max_heart_rate', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.33679753313289185
# slope: [-0.00036871  0.14504144  0.08278839  0.00585393 -0.13120191 -0.00024827
#  -0.01185854]
# model-params: ['age', 'chest_pain', 'resting_ECG', 'max_heart_rate', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.256708005086283
# slope: [ 0.0027864  -0.00288189  0.08469151  0.00798038 -0.15269833 -0.00043221
#   0.05354217]
# model-params: ['age', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.39494062105273064
# slope: [-0.26146601  0.14494307 -0.00348253  0.05423887  0.00575286 -0.11264017
#  -0.00065344]
# model-params: ['sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.256075014962217
# slope: [-0.24684015  0.14662823 -0.00374017  0.06462623  0.00570953 -0.1160302
#   0.02497547]
# model-params: ['sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.3060146541818086
# slope: [-0.29080447  0.15943016 -0.00404431  0.06030068  0.00657362 -0.00080223
#  -0.01775117]
# model-params: ['sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.2703306373719854
# slope: [-0.26427342  0.17849401 -0.00389502  0.06007099 -0.13428169 -0.00057822
#   0.02327301]
# model-params: ['sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.47194749545818726
# slope: [-0.26749609  0.14475659 -0.00370281  0.0057803  -0.11446664 -0.00073748
#   0.01919176]
# model-params: ['sex', 'chest_pain', 'resting_BP', 'max_heart_rate', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.05567613922520931
# slope: [-0.25450242  0.13978164  0.06537305  0.005883   -0.11843752 -0.00076815
#  -0.00276489]
# model-params: ['sex', 'chest_pain', 'resting_ECG', 'max_heart_rate', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.2761942674508477
# slope: [-0.27391919 -0.00300954  0.06248033  0.0074902  -0.13322607 -0.00087472
#   0.06952613]
# model-params: ['sex', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.03741622406928247
# slope: [ 1.48613121e-01 -3.16076060e-03  7.46081012e-02  5.79558627e-03
#  -1.28016975e-01 -1.44193542e-04  1.11403247e-02]
# model-params: ['chest_pain', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.38548094747607764
# slope: [-0.00408056 -0.28164166  0.16377349 -0.00382556  0.0672863   0.0059003 ]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'max_heart_rate']
# <class 'numpy.float64'>
# intercept: 1.3784207081897433
# slope: [-0.00646467 -0.26517493  0.17949045 -0.00317641  0.05891917 -0.12042598]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'caa']
# <class 'numpy.float64'>
# intercept: 1.6243954608238969
# slope: [-0.0096239  -0.31182722  0.19646554 -0.00337726  0.05757827 -0.00048506]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 1.5241108089482664
# slope: [-0.01003999 -0.30122195  0.19845586 -0.00343764  0.06371934 -0.00681396]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.3931459300843746
# slope: [-0.00139552 -0.2534902   0.14946764 -0.00371131  0.0055293  -0.11383276]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'max_heart_rate', 'caa']
# <class 'numpy.float64'>
# intercept: 0.5841452628858347
# slope: [-0.00351678 -0.30245963  0.16112734 -0.00386337  0.00605499 -0.00079254]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'max_heart_rate', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.46406628006393486
# slope: [-0.00441164 -0.28625892  0.1657797  -0.00396321  0.00587819 -0.0162498 ]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'max_heart_rate', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.5440846861972417
# slope: [-0.00628964 -0.28008214  0.17868312 -0.00323873 -0.12046186 -0.00050707]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 1.4625242166951105
# slope: [-0.00682818 -0.27070943  0.17946129 -0.00342003 -0.12229888  0.02702389]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.703985081884845
# slope: [-0.00981016 -0.3174598   0.19770913 -0.00348266 -0.00056888 -0.01278954]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.027470633339467976
# slope: [-0.00297794 -0.24416583  0.14462633  0.07241695  0.00539315 -0.11575722]
# model-params: ['age', 'sex', 'chest_pain', 'resting_ECG', 'max_heart_rate', 'caa']
# <class 'numpy.float64'>
# intercept: 0.15224151673862124
# slope: [-0.00530137 -0.29358363  0.15659982  0.0678523   0.00591109 -0.00077454]
# model-params: ['age', 'sex', 'chest_pain', 'resting_ECG', 'max_heart_rate', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.011215453957403976
# slope: [-0.00605567 -0.27598739  0.16158719  0.0766185   0.00574496 -0.03581593]
# model-params: ['age', 'sex', 'chest_pain', 'resting_ECG', 'max_heart_rate', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.1514044340503236
# slope: [-0.00758989 -0.27133944  0.17386873  0.06141627 -0.12204321 -0.00048887]
# model-params: ['age', 'sex', 'chest_pain', 'resting_ECG', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 1.0457101085338878
# slope: [-0.00809294 -0.2610285   0.17497797  0.06856635 -0.12315131  0.0105573 ]
# model-params: ['age', 'sex', 'chest_pain', 'resting_ECG', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.2811068064376212
# slope: [-0.01117372 -0.30782956  0.19345126  0.06507511 -0.00055103 -0.03036283]
# model-params: ['age', 'sex', 'chest_pain', 'resting_ECG', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.17401818482780684
# slope: [-0.00247817 -0.26556261  0.14207159  0.00554582 -0.1154005  -0.00079767]
# model-params: ['age', 'sex', 'chest_pain', 'max_heart_rate', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.04648352148561807
# slope: [-0.0034679  -0.24939156  0.14609174  0.00535584 -0.11664146 -0.00467936]
# model-params: ['age', 'sex', 'chest_pain', 'max_heart_rate', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.22706567745096617
# slope: [-0.00543218 -0.29874789  0.15894009  0.00591529 -0.00087524 -0.04341509]
# model-params: ['age', 'sex', 'chest_pain', 'max_heart_rate', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.2280964934550314
# slope: [-0.00790967 -0.27786101  0.17428008 -0.12295531 -0.00058106  0.00369736]
# model-params: ['age', 'sex', 'chest_pain', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.03419903613827446
# slope: [ 2.25155739e-04 -2.50859770e-01 -3.03112720e-03  7.28761991e-02
#   7.53663408e-03 -1.34161549e-01]
# model-params: ['age', 'sex', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'caa']
# <class 'numpy.float64'>
# intercept: 0.25723089603202776
# slope: [-0.00214447 -0.31170144 -0.00317221  0.06640828  0.00836304 -0.00102401]
# model-params: ['age', 'sex', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.10582075823494935
# slope: [-0.00340171 -0.29261961 -0.00341258  0.08141943  0.00818508  0.03294316]
# model-params: ['age', 'sex', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.6489530708906541
# slope: [-0.0067084  -0.29046515 -0.00223879  0.06189982 -0.15032074 -0.00068877]
# model-params: ['age', 'sex', 'resting_BP', 'resting_ECG', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 1.5483748055208861
# slope: [-0.00750315 -0.27889673 -0.00262622  0.0744035  -0.1548313   0.09389802]
# model-params: ['age', 'sex', 'resting_BP', 'resting_ECG', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.8988510142021533
# slope: [-0.01149906 -0.34279796 -0.00262749  0.0705441  -0.00078674  0.04974304]
# model-params: ['age', 'sex', 'resting_BP', 'resting_ECG', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.2762614156915137
# slope: [ 0.00096021 -0.27633182 -0.00305836  0.00769208 -0.13292245 -0.00100186]
# model-params: ['age', 'sex', 'resting_BP', 'max_heart_rate', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.16500721436790816
# slope: [-0.00035922 -0.25908438 -0.00342809  0.007471   -0.13776728  0.06575243]
# model-params: ['age', 'sex', 'resting_BP', 'max_heart_rate', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.3701303336260776
# slope: [-0.00250789 -0.32020925 -0.00341152  0.00835775 -0.00111954  0.02393579]
# model-params: ['age', 'sex', 'resting_BP', 'max_heart_rate', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.7770257743807785
# slope: [-0.00713725 -0.30000392 -0.00266197 -0.15417108 -0.00076943  0.08630154]
# model-params: ['age', 'sex', 'resting_BP', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.08033966561519157
# slope: [-0.00037974 -0.26703162  0.06817504  0.00752062 -0.13390484 -0.00095752]
# model-params: ['age', 'sex', 'resting_ECG', 'max_heart_rate', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: -0.23867860861282464
# slope: [-0.00167582 -0.2485507   0.08345098  0.00730621 -0.13798406  0.04960607]
# model-params: ['age', 'sex', 'resting_ECG', 'max_heart_rate', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.03124111592338652
# slope: [-0.00393787 -0.30951409  0.07499929  0.00818616 -0.00107344  0.00704621]
# model-params: ['age', 'sex', 'resting_ECG', 'max_heart_rate', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.4211129693055207
# slope: [-0.00805129 -0.28988692  0.07100648 -0.15406007 -0.00071837  0.07394679]
# model-params: ['age', 'sex', 'resting_ECG', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.017753972985098843
# slope: [-0.00091584 -0.27555279  0.00747636 -0.13643231 -0.00105742  0.03999865]
# model-params: ['age', 'sex', 'max_heart_rate', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.058899692815802984
# slope: [ 0.00108394  0.14901702 -0.00330419  0.07722079  0.00594095 -0.12954295]
# model-params: ['age', 'chest_pain', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'caa']
# <class 'numpy.float64'>
# intercept: -0.006993732428308697
# slope: [-0.00188062  0.1664473  -0.00356933  0.0830673   0.00645342 -0.00019066]
# model-params: ['age', 'chest_pain', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'cholesterol']
# <class 'numpy.float64'>
# intercept: -0.046197837116389806
# slope: [-0.00201075  0.16846255 -0.00350094  0.08384437  0.00640734 -0.03460303]
# model-params: ['age', 'chest_pain', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.048718866227439
# slope: [-4.64248445e-03  1.82886068e-01 -2.90850165e-03  7.53620129e-02
#  -1.38650661e-01  6.31074114e-05]
# model-params: ['age', 'chest_pain', 'resting_BP', 'resting_ECG', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 1.0656055699484699
# slope: [-0.00460723  0.18206445 -0.00294019  0.07522448 -0.13935209  0.01540384]
# model-params: ['age', 'chest_pain', 'resting_BP', 'resting_ECG', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.1573803751252667
# slope: [-8.47612295e-03  2.06524722e-01 -3.10176214e-03  8.25847337e-02
#   7.20364240e-05 -3.23359397e-02]
# model-params: ['age', 'chest_pain', 'resting_BP', 'resting_ECG', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.0641069863952225
# slope: [ 0.00108075  0.14923772 -0.00345583  0.00599157 -0.13084979 -0.00027991]
# model-params: ['age', 'chest_pain', 'resting_BP', 'max_heart_rate', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.03405612502585864
# slope: [ 0.00070141  0.15047813 -0.00352149  0.00591716 -0.13109457  0.00334782]
# model-params: ['age', 'chest_pain', 'resting_BP', 'max_heart_rate', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.08325072649855547
# slope: [-0.00202295  0.16919316 -0.00364326  0.00646758 -0.00030132 -0.0433261 ]
# model-params: ['age', 'chest_pain', 'resting_BP', 'max_heart_rate', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.15259850858977
# slope: [-4.90320037e-03  1.83651244e-01 -3.11708233e-03 -1.40374197e-01
#  -3.11342182e-05  8.54677405e-03]
# model-params: ['age', 'chest_pain', 'resting_BP', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.3351173428548172
# slope: [-0.00041468  0.14455334  0.08336969  0.00584892 -0.13175606 -0.00024674]
# model-params: ['age', 'chest_pain', 'resting_ECG', 'max_heart_rate', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: -0.37213838584806436
# slope: [-0.00070966  0.14612464  0.08585878  0.00578734 -0.13129037 -0.01120066]
# model-params: ['age', 'chest_pain', 'resting_ECG', 'max_heart_rate', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.34208372882440385
# slope: [-0.00353728  0.16487827  0.08926722  0.00632444 -0.00026554 -0.05836067]
# model-params: ['age', 'chest_pain', 'resting_ECG', 'max_heart_rate', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.7589055827274447
# slope: [-6.04982778e-03  1.79115229e-01  8.25899874e-02 -1.40278714e-01
#   2.48737696e-06 -3.74991159e-03]
# model-params: ['age', 'chest_pain', 'resting_ECG', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.2466366390986371
# slope: [-0.00070386  0.1463794   0.00585205 -0.13238896 -0.00035808 -0.02079615]
# model-params: ['age', 'chest_pain', 'max_heart_rate', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.2815624543336399
# slope: [ 0.00293589 -0.00272268  0.08255594  0.0080245  -0.15058948 -0.00044556]
# model-params: ['age', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: -0.31426538114873426
# slope: [ 0.00224945 -0.0029542   0.09000778  0.00789352 -0.15312486  0.0557809 ]
# model-params: ['age', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.28086216316389967
# slope: [-0.00064768 -0.00301338  0.09345517  0.0088699  -0.00048894  0.00651471]
# model-params: ['age', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.2367757115913447
# slope: [-5.34218697e-03 -2.23879085e-03  8.86332561e-02 -1.73942854e-01
#  -1.56267832e-04  7.70378828e-02]
# model-params: ['age', 'resting_BP', 'resting_ECG', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.15017853954836213
# slope: [ 0.00255252 -0.00306083  0.00800626 -0.1540722  -0.00054307  0.04607637]
# model-params: ['age', 'resting_BP', 'max_heart_rate', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.5202036778407311
# slope: [ 0.00130507  0.09096794  0.00783232 -0.15342133 -0.0004851   0.03402036]
# model-params: ['age', 'resting_ECG', 'max_heart_rate', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.2478842496470099
# slope: [-0.24607491  0.14763581 -0.0036622   0.06361572  0.00570836 -0.1148656 ]
# model-params: ['sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'caa']
# <class 'numpy.float64'>
# intercept: 0.3110003736884447
# slope: [-0.29154763  0.15882037 -0.00410458  0.0610832   0.0065805  -0.00080237]
# model-params: ['sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.12257570805558432
# slope: [-0.27255096  0.16309345 -0.00428062  0.07202595  0.00653885 -0.01787706]
# model-params: ['sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.2628300377767374
# slope: [-0.26358968  0.17942166 -0.00382196  0.0591104  -0.13318858 -0.00057949]
# model-params: ['sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 1.1343617681012048
# slope: [-0.25064768  0.18061638 -0.00405387  0.06836882 -0.13614252  0.02392793]
# model-params: ['sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.3030818457345177
# slope: [-0.29931153  0.20317878 -0.00454146  0.06703669 -0.00074729 -0.02776636]
# model-params: ['sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.46486728744239275
# slope: [-0.26685394  0.14551816 -0.0036403   0.00577909 -0.11355484 -0.0007373 ]
# model-params: ['sex', 'chest_pain', 'resting_BP', 'max_heart_rate', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.3161102902656575
# slope: [-0.25080148  0.14798526 -0.00394118  0.00573415 -0.11721075  0.0190434 ]
# model-params: ['sex', 'chest_pain', 'resting_BP', 'max_heart_rate', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.38112243269385637
# slope: [-0.29680325  0.16039152 -0.00420506  0.00660788 -0.00089646 -0.0235493 ]
# model-params: ['sex', 'chest_pain', 'resting_BP', 'max_heart_rate', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.3501081798240875
# slope: [-0.2700696   0.17952158 -0.0040536  -0.13513624 -0.00067071  0.01777068]
# model-params: ['sex', 'chest_pain', 'resting_BP', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.05592594455690869
# slope: [-0.25456642  0.13965755  0.06551515  0.00588345 -0.11858175 -0.00076828]
# model-params: ['sex', 'chest_pain', 'resting_ECG', 'max_heart_rate', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: -0.2576446172445862
# slope: [-0.23580471  0.14268697  0.07714682  0.00583807 -0.12140089 -0.0035349 ]
# model-params: ['sex', 'chest_pain', 'resting_ECG', 'max_heart_rate', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.22226196998323156
# slope: [-0.28337293  0.15536694  0.07212018  0.00675955 -0.00094186 -0.05058724]
# model-params: ['sex', 'chest_pain', 'resting_ECG', 'max_heart_rate', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.7890191989396074
# slope: [-0.25590596  0.17474907  0.07130597 -0.13990029 -0.00070366 -0.00637721]
# model-params: ['sex', 'chest_pain', 'resting_ECG', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.004868988294964294
# slope: [-0.26047254  0.14051666  0.0059207  -0.11948725 -0.00087553 -0.01009517]
# model-params: ['sex', 'chest_pain', 'max_heart_rate', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.2514803396557028
# slope: [-0.27208199 -0.00277789  0.05971866  0.00752122 -0.1303113  -0.0008829 ]
# model-params: ['sex', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.07526394604172132
# slope: [-0.2535082  -0.00324097  0.07533249  0.00747356 -0.1367547   0.07164057]
# model-params: ['sex', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.1447955077849516
# slope: [-0.30957053 -0.00351862  0.06944615  0.0086904  -0.00108229  0.02523083]
# model-params: ['sex', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.4513515567456339
# slope: [-0.28081083 -0.00329691  0.07169836 -0.16854822 -0.00084591  0.08339958]
# model-params: ['sex', 'resting_BP', 'resting_ECG', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.3539123569210832
# slope: [-0.28001145 -0.00316939  0.0075308  -0.13412896 -0.00097271  0.06408625]
# model-params: ['sex', 'resting_BP', 'max_heart_rate', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.10999561311177464
# slope: [-0.26710845  0.07091074  0.00755695 -0.13670608 -0.00096778  0.04546135]
# model-params: ['sex', 'resting_ECG', 'max_heart_rate', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.034349753314091624
# slope: [ 1.49054919e-01 -3.12626166e-03  7.41238186e-02  5.79505100e-03
#  -1.27476884e-01 -1.45432952e-04]
# model-params: ['chest_pain', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.008421000796660971
# slope: [ 0.14916594 -0.00320822  0.0765204   0.00578474 -0.12834638  0.01148717]
# model-params: ['chest_pain', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.11824644680642826
# slope: [ 0.16682741 -0.00366531  0.08279525  0.00673587 -0.00025216 -0.03839975]
# model-params: ['chest_pain', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.9085458925332526
# slope: [ 1.83426182e-01 -3.49645192e-03  7.96316237e-02 -1.48787859e-01
#  -6.56575210e-05  1.00557521e-02]
# model-params: ['chest_pain', 'resting_BP', 'resting_ECG', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.1216800847232658
# slope: [ 0.14981074 -0.00334597  0.00583263 -0.12935056 -0.00024629  0.0039047 ]
# model-params: ['chest_pain', 'resting_BP', 'max_heart_rate', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.36143397887992934
# slope: [ 0.14475932  0.08313375  0.00590953 -0.13180014 -0.00026084 -0.01258693]
# model-params: ['chest_pain', 'resting_ECG', 'max_heart_rate', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.1101563423489269
# slope: [-0.00257477  0.08299078  0.00759238 -0.14878347 -0.00035078  0.05734263]
# model-params: ['resting_BP', 'resting_ECG', 'max_heart_rate', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.5273212183594707
# slope: [-0.01006323 -0.30155194  0.19822256 -0.00345777  0.06398799]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'resting_ECG']
# <class 'numpy.float64'>
# intercept: 0.4731259031037034
# slope: [-0.00447378 -0.28710775  0.16525464 -0.00401281  0.005875  ]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'max_heart_rate']
# <class 'numpy.float64'>
# intercept: 1.4499570216371116
# slope: [-0.00676469 -0.26966536  0.18054455 -0.00334001 -0.12115335]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'caa']
# <class 'numpy.float64'>
# intercept: 1.7105561060537295
# slope: [-0.00985693 -0.3181113   0.19728282 -0.00352194 -0.00056847]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 1.599575349174825
# slope: [-0.01036782 -0.3060293   0.1999064  -0.00359931 -0.0124201 ]
# model-params: ['age', 'sex', 'chest_pain', 'resting_BP', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.01925769076549555
# slope: [-0.00624402 -0.27763341  0.1603033   0.07833128  0.00573387]
# model-params: ['age', 'sex', 'chest_pain', 'resting_ECG', 'max_heart_rate']
# <class 'numpy.float64'>
# intercept: 1.0444540679978824
# slope: [-0.00805507 -0.26069347  0.17544666  0.06808176 -0.12268723]
# model-params: ['age', 'sex', 'chest_pain', 'resting_ECG', 'caa']
# <class 'numpy.float64'>
# intercept: 1.2858216763612216
# slope: [-0.01132518 -0.3091707   0.19231077  0.06654807 -0.00055001]
# model-params: ['age', 'sex', 'chest_pain', 'resting_ECG', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 1.161337498854997
# slope: [-0.01172243 -0.29606359  0.19532701  0.07264116 -0.02999765]
# model-params: ['age', 'sex', 'chest_pain', 'resting_ECG', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.04767128640040935
# slope: [-0.00348813 -0.24956226  0.14589953  0.00535366 -0.11685303]
# model-params: ['age', 'sex', 'chest_pain', 'max_heart_rate', 'caa']
# <class 'numpy.float64'>
# intercept: 0.2391671093012644
# slope: [-0.00567448 -0.30092991  0.15741868  0.00590108 -0.00087641]
# model-params: ['age', 'sex', 'chest_pain', 'max_heart_rate', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.08903264547290851
# slope: [-0.00658331 -0.2816356   0.16337403  0.00570925 -0.04388264]
# model-params: ['age', 'sex', 'chest_pain', 'max_heart_rate', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.2274879368833194
# slope: [-0.00789535 -0.27773021  0.17444195 -0.12279041 -0.000581  ]
# model-params: ['age', 'sex', 'chest_pain', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 1.1083165320700064
# slope: [-0.00851368 -0.26577903  0.17627759 -0.12382762  0.00352872]
# model-params: ['age', 'sex', 'chest_pain', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.3611658661063633
# slope: [-0.01148607 -0.31451377  0.19443064 -0.00064883 -0.0371699 ]
# model-params: ['age', 'sex', 'chest_pain', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.0871507023240019
# slope: [-0.00327795 -0.29106692 -0.0033122   0.08021022  0.00820645]
# model-params: ['age', 'sex', 'resting_BP', 'resting_ECG', 'max_heart_rate']
# <class 'numpy.float64'>
# intercept: 1.5118469933884198
# slope: [-0.00731877 -0.27576429 -0.00234016  0.07112752 -0.15155851]
# model-params: ['age', 'sex', 'resting_BP', 'resting_ECG', 'caa']
# <class 'numpy.float64'>
# intercept: 1.8784995014525494
# slope: [-0.01134007 -0.34073276 -0.002472    0.06861808 -0.0007939 ]
# model-params: ['age', 'sex', 'resting_BP', 'resting_ECG', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 1.7451967466013452
# slope: [-0.01224766 -0.32655895 -0.00275263  0.081244    0.05200369]
# model-params: ['age', 'sex', 'resting_BP', 'resting_ECG', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.12582899473066084
# slope: [-1.63171618e-04 -2.56532436e-01 -3.22667137e-03  7.52606262e-03
#  -1.35313099e-01]
# model-params: ['age', 'sex', 'resting_BP', 'max_heart_rate', 'caa']
# <class 'numpy.float64'>
# intercept: 0.35582912254915644
# slope: [-0.00240993 -0.31905641 -0.00333575  0.00837372 -0.00112206]
# model-params: ['age', 'sex', 'resting_BP', 'max_heart_rate', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.20472706001509205
# slope: [-0.00384327 -0.29901631 -0.00361309  0.008184    0.02631824]
# model-params: ['age', 'sex', 'resting_BP', 'max_heart_rate', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.7415542667012782
# slope: [-0.00694275 -0.29709231 -0.00238912 -0.15109671 -0.0007793 ]
# model-params: ['age', 'sex', 'resting_BP', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 1.6373083659432532
# slope: [-0.00787639 -0.28444378 -0.00280865 -0.15577693  0.08810095]
# model-params: ['age', 'sex', 'resting_BP', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 2.003021631152953
# slope: [-0.01177365 -0.35037911 -0.00278119 -0.0008911   0.04381651]
# model-params: ['age', 'sex', 'resting_BP', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.25215298622664417
# slope: [-0.0014554  -0.24694946  0.08131946  0.00735627 -0.13606711]
# model-params: ['age', 'sex', 'resting_ECG', 'max_heart_rate', 'caa']
# <class 'numpy.float64'>
# intercept: -0.033064947954076995
# slope: [-0.00389817 -0.30922198  0.07466889  0.00819207 -0.00107424]
# model-params: ['age', 'sex', 'resting_ECG', 'max_heart_rate', 'cholesterol']
# <class 'numpy.float64'>
# intercept: -0.22270959878785124
# slope: [-0.00522308 -0.28782619  0.08999003  0.00801177  0.00943434]
# model-params: ['age', 'sex', 'resting_ECG', 'max_heart_rate', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.4182340442852266
# slope: [-0.00778575 -0.28794217  0.06767377 -0.1513553  -0.00072696]
# model-params: ['age', 'sex', 'resting_ECG', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 1.2669376464515782
# slope: [-0.00874623 -0.27444373  0.08099994 -0.15546317  0.07559472]
# model-params: ['age', 'sex', 'resting_ECG', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.6280842021882334
# slope: [-0.01271366 -0.33952665  0.07650963 -0.00083411  0.0311731 ]
# model-params: ['age', 'sex', 'resting_ECG', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.0056801072122666385
# slope: [-0.00072241 -0.27419663  0.00751781 -0.13484835 -0.00106061]
# model-params: ['age', 'sex', 'max_heart_rate', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: -0.15676913474934473
# slope: [-0.00221143 -0.25452343  0.00728868 -0.13914264  0.0416918 ]
# model-params: ['age', 'sex', 'max_heart_rate', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.06142680837242381
# slope: [-0.00429813 -0.3173786   0.00819458 -0.00118815 -0.00047125]
# model-params: ['age', 'sex', 'max_heart_rate', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.5094663050610844
# slope: [-0.00837902 -0.29712756 -0.15477965 -0.00082616  0.06705525]
# model-params: ['age', 'sex', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.031188910138959636
# slope: [-0.00212334  0.16733599 -0.00360144  0.08531372  0.00640409]
# model-params: ['age', 'chest_pain', 'resting_BP', 'resting_ECG', 'max_heart_rate']
# <class 'numpy.float64'>
# intercept: 1.0598084511850214
# slope: [-0.00457792  0.18268565 -0.00289677  0.07461175 -0.1386684 ]
# model-params: ['age', 'chest_pain', 'resting_BP', 'resting_ECG', 'caa']
# <class 'numpy.float64'>
# intercept: 1.169836057313346
# slope: [-8.58404118e-03  2.05471680e-01 -3.19691723e-03  8.40259225e-02
#   7.76848517e-05]
# model-params: ['age', 'chest_pain', 'resting_BP', 'resting_ECG', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 1.1699484925179617
# slope: [-0.00840217  0.20630788 -0.00308765  0.08171846 -0.032597  ]
# model-params: ['age', 'chest_pain', 'resting_BP', 'resting_ECG', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.03247894630379056
# slope: [ 0.00070923  0.15060559 -0.00351175  0.00591805 -0.13094227]
# model-params: ['age', 'chest_pain', 'resting_BP', 'max_heart_rate', 'caa']
# <class 'numpy.float64'>
# intercept: 0.10362335115268412
# slope: [-0.00218086  0.16785172 -0.00377519  0.00646168 -0.00029595]
# model-params: ['age', 'chest_pain', 'resting_BP', 'max_heart_rate', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.04960820033852975
# slope: [-0.00242807  0.17065538 -0.00370605  0.00638872 -0.0425507 ]
# model-params: ['age', 'chest_pain', 'resting_BP', 'max_heart_rate', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.1491612071367903
# slope: [-4.88430243e-03  1.83986089e-01 -3.09185081e-03 -1.39988914e-01
#  -3.21358350e-05]
# model-params: ['age', 'chest_pain', 'resting_BP', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 1.1475775809359026
# slope: [-0.00493691  0.18375404 -0.0031241  -0.14037549  0.00862454]
# model-params: ['age', 'chest_pain', 'resting_BP', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.2652482744253595
# slope: [-8.75478619e-03  2.08227997e-01 -3.28124425e-03 -3.32549071e-05
#  -4.04319848e-02]
# model-params: ['age', 'chest_pain', 'resting_BP', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.3703450488069109
# slope: [-0.00075111  0.14565715  0.08639015  0.005783   -0.13181344]
# model-params: ['age', 'chest_pain', 'resting_ECG', 'max_heart_rate', 'caa']
# <class 'numpy.float64'>
# intercept: -0.33378729915786864
# slope: [-0.00383432  0.16285497  0.09231317  0.00630932 -0.00025824]
# model-params: ['age', 'chest_pain', 'resting_ECG', 'max_heart_rate', 'cholesterol']
# <class 'numpy.float64'>
# intercept: -0.3798879093151907
# slope: [-0.00390424  0.16605115  0.09255597  0.00625355 -0.05769055]
# model-params: ['age', 'chest_pain', 'resting_ECG', 'max_heart_rate', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.7591405706712073
# slope: [-6.06283627e-03  1.78951568e-01  8.27739687e-02 -1.40451592e-01
#   2.90367495e-06]
# model-params: ['age', 'chest_pain', 'resting_ECG', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.7593900983024752
# slope: [-0.00604703  0.17910818  0.08255885 -0.14027886 -0.00375564]
# model-params: ['age', 'chest_pain', 'resting_ECG', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.8479071930730075
# slope: [-9.94748101e-03  2.03387483e-01  8.95386275e-02  5.59319250e-06
#  -5.30464567e-02]
# model-params: ['age', 'chest_pain', 'resting_ECG', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.24255832419308831
# slope: [-0.00078907  0.14553544  0.00584319 -0.13338063 -0.00035674]
# model-params: ['age', 'chest_pain', 'max_heart_rate', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: -0.29355534813940787
# slope: [-0.00122204  0.1480405   0.0057543  -0.13258322 -0.02031753]
# model-params: ['age', 'chest_pain', 'max_heart_rate', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.24484976938206304
# slope: [-0.00392985  0.16651561  0.006327   -0.00038419 -0.06845853]
# model-params: ['age', 'chest_pain', 'max_heart_rate', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.8484986315348927
# slope: [-6.38235375e-03  1.80439037e-01 -1.41460005e-01 -1.07138443e-04
#  -1.26687182e-02]
# model-params: ['age', 'chest_pain', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.34204764729824866
# slope: [ 0.00238809 -0.00279046  0.08795138  0.00793674 -0.15093874]
# model-params: ['age', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'caa']
# <class 'numpy.float64'>
# intercept: -0.28388235949812335
# slope: [-0.00062342 -0.00299354  0.09317723  0.00887382 -0.00049049]
# model-params: ['age', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'cholesterol']
# <class 'numpy.float64'>
# intercept: -0.34607537583358094
# slope: [-0.00126619 -0.00309563  0.09949922  0.00877442  0.00889959]
# model-params: ['age', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.2128353064072583
# slope: [-0.00519138 -0.00200404  0.0855845  -0.17107059 -0.00017333]
# model-params: ['age', 'resting_BP', 'resting_ECG', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 1.2099015532225823
# slope: [-0.00550547 -0.00226767  0.09055322 -0.17401396  0.07775987]
# model-params: ['age', 'resting_BP', 'resting_ECG', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.401443096620971
# slope: [-0.010364   -0.00230799  0.0992818  -0.00018633  0.02565404]
# model-params: ['age', 'resting_BP', 'resting_ECG', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.17396263491172248
# slope: [ 0.00268672 -0.00291944  0.00804379 -0.15222107 -0.00055219]
# model-params: ['age', 'resting_BP', 'max_heart_rate', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: -0.21514290341086018
# slope: [ 0.00184805 -0.00316753  0.00789741 -0.15472703  0.04833687]
# model-params: ['age', 'resting_BP', 'max_heart_rate', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.16343978775958545
# slope: [-0.00094012 -0.00321232  0.00890732 -0.00061195 -0.00219865]
# model-params: ['age', 'resting_BP', 'max_heart_rate', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.3533483325771094
# slope: [-0.00561457 -0.00242391 -0.17545297 -0.00027137  0.06930316]
# model-params: ['age', 'resting_BP', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.5268814956822616
# slope: [ 0.00145507  0.08935828  0.00786623 -0.15202794 -0.00049187]
# model-params: ['age', 'resting_ECG', 'max_heart_rate', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: -0.5924477665625516
# slope: [ 0.0006587   0.0971305   0.00773035 -0.15392196  0.0359893 ]
# model-params: ['age', 'resting_ECG', 'max_heart_rate', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.5565590207267201
# slope: [-0.00221393  0.10006278  0.00871945 -0.00054454 -0.01413507]
# model-params: ['age', 'resting_ECG', 'max_heart_rate', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.0096134079309427
# slope: [-0.0063801   0.09347232 -0.17419938 -0.00020152  0.06146929]
# model-params: ['age', 'resting_ECG', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.42290515391686156
# slope: [ 0.00095345  0.00785032 -0.15495228 -0.00060827  0.0246562 ]
# model-params: ['age', 'max_heart_rate', 'caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.12756534960593208
# slope: [-0.27329626  0.16247997 -0.00434136  0.07281603  0.00654577]
# model-params: ['sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'max_heart_rate']
# <class 'numpy.float64'>
# intercept: 1.126341470886898
# slope: [-0.24991378  0.18157501 -0.00397911  0.06739994 -0.13502279]
# model-params: ['sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'caa']
# <class 'numpy.float64'>
# intercept: 1.3125171264752395
# slope: [-0.30048859  0.202296   -0.00463661  0.06827245 -0.00074742]
# model-params: ['sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 1.1272286438994197
# slope: [-0.28225996  0.20637681 -0.00475922  0.07792976 -0.02783431]
# model-params: ['sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.3091232493455105
# slope: [-0.25016842  0.14874014 -0.0038791   0.00573296 -0.11630532]
# model-params: ['sex', 'chest_pain', 'resting_BP', 'max_heart_rate', 'caa']
# <class 'numpy.float64'>
# intercept: 0.3890633427650513
# slope: [-0.29789705  0.15959574 -0.00428814  0.00661764 -0.00089827]
# model-params: ['sex', 'chest_pain', 'resting_BP', 'max_heart_rate', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.1880475091387253
# slope: [-0.2772629   0.16479455 -0.00451104  0.00657574 -0.02498256]
# model-params: ['sex', 'chest_pain', 'resting_BP', 'max_heart_rate', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.343381379080411
# slope: [-0.26947449  0.18022001 -0.00399566 -0.13428792 -0.00067055]
# model-params: ['sex', 'chest_pain', 'resting_BP', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 1.2018973121542866
# slope: [-0.25485684  0.18220745 -0.004268   -0.13748352  0.01764598]
# model-params: ['sex', 'chest_pain', 'resting_BP', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.3924087268851664
# slope: [-0.30603362  0.20450178 -0.00472315 -0.00085179 -0.034274  ]
# model-params: ['sex', 'chest_pain', 'resting_BP', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.25800977380325507
# slope: [-0.23588231  0.14252898  0.07733117  0.00583863 -0.12158597]
# model-params: ['sex', 'chest_pain', 'resting_ECG', 'max_heart_rate', 'caa']
# <class 'numpy.float64'>
# intercept: -0.23072243705034012
# slope: [-0.28522626  0.15340247  0.07492961  0.00678781 -0.00094836]
# model-params: ['sex', 'chest_pain', 'resting_ECG', 'max_heart_rate', 'cholesterol']
# <class 'numpy.float64'>
# intercept: -0.47645388879766437
# slope: [-0.26120709  0.15943044  0.08684687  0.00673119 -0.05301224]
# model-params: ['sex', 'chest_pain', 'resting_ECG', 'max_heart_rate', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.7885903372694203
# slope: [-0.25605384  0.17446893  0.07163479 -0.14023674 -0.00070396]
# model-params: ['sex', 'chest_pain', 'resting_ECG', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.5979744707624894
# slope: [-0.23875713  0.17716743  0.08205671 -0.14246638 -0.00705774]
# model-params: ['sex', 'chest_pain', 'resting_ECG', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.7395739006413029
# ...
# intercept: 1.2828759026908365
# slope: [-0.00577961 -0.00226364 -0.17296564]
# model-params: ['age', 'resting_BP', 'caa']
# <class 'numpy.float64'>
# intercept: 1.527037579942257
# slope: [-0.01066505 -0.00246354 -0.00031837]
# model-params: ['age', 'resting_BP', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 1.4839849041927027
# slope: [-0.01107189 -0.00258388  0.01755501]
# model-params: ['age', 'resting_BP', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.635197618113498
# slope: [-0.00301525  0.10759808  0.00859933]
# model-params: ['age', 'resting_ECG', 'max_heart_rate']
# <class 'numpy.float64'>
# intercept: 0.9689902159363766
# slope: [-0.00640622  0.09323533 -0.17190996]
# model-params: ['age', 'resting_ECG', 'caa']
# <class 'numpy.float64'>
# intercept: 1.1671479063957377
# slope: [-0.01139773  0.10380942 -0.00023454]
# model-params: ['age', 'resting_ECG', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 1.1229851224014618
# slope: [-0.01170938  0.10726126  0.01027232]
# model-params: ['age', 'resting_ECG', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.5137022905840474
# slope: [ 0.00021505  0.00774719 -0.15462146]
# model-params: ['age', 'max_heart_rate', 'caa']
# <class 'numpy.float64'>
# intercept: -0.4437290553568277
# slope: [-0.00278121  0.00873006 -0.00067789]
# model-params: ['age', 'max_heart_rate', 'cholesterol']
# <class 'numpy.float64'>
# intercept: -0.5437840603971438
# slope: [-0.00361739  0.00861007 -0.0233445 ]
# model-params: ['age', 'max_heart_rate', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.110399457136893
# slope: [-0.00656997 -0.17377339 -0.00033263]
# model-params: ['age', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 1.0541352554302783
# slope: [-0.00715484 -0.1760545   0.05259301]
# model-params: ['age', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.2848479335809566
# slope: [-0.01191815 -0.00037397 -0.00168996]
# model-params: ['age', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.2179179202884722
# slope: [-0.28903691  0.20738978 -0.00513925]
# model-params: ['sex', 'chest_pain', 'resting_BP']
# <class 'numpy.float64'>
# intercept: 0.48375561427170505
# slope: [-0.2722406   0.20137508  0.09858096]
# model-params: ['sex', 'chest_pain', 'resting_ECG']
# <class 'numpy.float64'>
# intercept: -0.4472284279132964
# slope: [-0.26858845  0.15887454  0.00682702]
# model-params: ['sex', 'chest_pain', 'max_heart_rate']
# <class 'numpy.float64'>
# intercept: 0.6446927462831622
# slope: [-0.24351692  0.17816092 -0.14540746]
# model-params: ['sex', 'chest_pain', 'caa']
# <class 'numpy.float64'>
# intercept: 0.8181357609678334
# slope: [-0.30217899  0.19887015 -0.00105354]
# model-params: ['sex', 'chest_pain', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.5452186408047894
# slope: [-0.27546057  0.20612439 -0.07945238]
# model-params: ['sex', 'chest_pain', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.2583322825402905
# slope: [-0.30332908 -0.0042432   0.09838606]
# model-params: ['sex', 'resting_BP', 'resting_ECG']
# <class 'numpy.float64'>
# intercept: -0.04139425084377757
# slope: [-0.2903245  -0.00402466  0.00878087]
# model-params: ['sex', 'resting_BP', 'max_heart_rate']
# <class 'numpy.float64'>
# intercept: 1.3115105377849932
# slope: [-0.26391198 -0.00351087 -0.17075792]
# model-params: ['sex', 'resting_BP', 'caa']
# <class 'numpy.float64'>
# intercept: 1.63150659045271
# slope: [-0.33707784 -0.00417711 -0.00124608]
# model-params: ['sex', 'resting_BP', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 1.3681467493540027
# slope: [-0.31137055 -0.00466344  0.01983132]
# model-params: ['sex', 'resting_BP', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.6423814681165163
# slope: [-0.27510049  0.09900326  0.00883812]
# model-params: ['sex', 'resting_ECG', 'max_heart_rate']
# <class 'numpy.float64'>
# intercept: 0.7929450501557612
# slope: [-0.24941594  0.09290886 -0.17420211]
# model-params: ['sex', 'resting_ECG', 'caa']
# <class 'numpy.float64'>
# intercept: 1.0215943858351193
# slope: [-0.3219502   0.09499885 -0.00124768]
# model-params: ['sex', 'resting_ECG', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.6852999602587792
# slope: [-0.29292957  0.11462663 -0.00777174]
# model-params: ['sex', 'resting_ECG', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.3231617563274306
# slope: [-0.24755552  0.0076176  -0.14137098]
# model-params: ['sex', 'max_heart_rate', 'caa']
# <class 'numpy.float64'>
# intercept: -0.24270308173863264
# slope: [-0.31089681  0.00887633 -0.0013346 ]
# model-params: ['sex', 'max_heart_rate', 'cholesterol']
# <class 'numpy.float64'>
# intercept: -0.5974619101810315
# slope: [-0.28078807  0.00893094 -0.01781384]
# model-params: ['sex', 'max_heart_rate', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.1269222512185841
# slope: [-0.27979518 -0.17215157 -0.00107875]
# model-params: ['sex', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.843266297363777
# slope: [-0.25574229 -0.17955807  0.04691777]
# model-params: ['sex', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.120053288318547
# slope: [-0.33113198 -0.00140804 -0.01704428]
# model-params: ['sex', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.8678484200491483
# slope: [ 0.21107143 -0.0043883   0.09507625]
# model-params: ['chest_pain', 'resting_BP', 'resting_ECG']
# <class 'numpy.float64'>
# intercept: -0.0842696957664888
# slope: [ 0.16848456 -0.00418016  0.00679004]
# model-params: ['chest_pain', 'resting_BP', 'max_heart_rate']
# <class 'numpy.float64'>
# intercept: 0.968711147814552
# slope: [ 0.18568575 -0.00375196 -0.15063213]
# model-params: ['chest_pain', 'resting_BP', 'caa']
# <class 'numpy.float64'>
# intercept: 1.0203535566761122
# slope: [ 0.21222802 -0.00460638 -0.00030339]
# model-params: ['chest_pain', 'resting_BP', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.9392273207505153
# slope: [ 0.21523875 -0.00451352 -0.05872206]
# model-params: ['chest_pain', 'resting_BP', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.7022891106716131
# slope: [0.16190346 0.10275672 0.00692312]
# model-params: ['chest_pain', 'resting_ECG', 'max_heart_rate']
# <class 'numpy.float64'>
# intercept: 0.43457521436258584
# slope: [ 0.1798032   0.09281593 -0.15479265]
# model-params: ['chest_pain', 'resting_ECG', 'caa']
# <class 'numpy.float64'>
# intercept: 0.3727706558646184
# slope: [ 0.2059316   0.1071501  -0.00034082]
# model-params: ['chest_pain', 'resting_ECG', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.29734291682866776
# slope: [ 0.20996787  0.10711494 -0.08341956]
# model-params: ['chest_pain', 'resting_ECG', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.3867892450123691
# slope: [ 0.14627898  0.00594118 -0.13598832]
# model-params: ['chest_pain', 'max_heart_rate', 'caa']
# <class 'numpy.float64'>
# intercept: -0.5286675292218939
# slope: [ 0.16149617  0.00702044 -0.00054223]
# model-params: ['chest_pain', 'max_heart_rate', 'cholesterol']
# <class 'numpy.float64'>
# intercept: -0.6450480441890329
# slope: [ 0.16667645  0.0069528  -0.08105607]
# model-params: ['chest_pain', 'max_heart_rate', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.5650221884112353
# slope: [ 0.18025188 -0.15698428 -0.00032595]
# model-params: ['chest_pain', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.48622101307067567
# slope: [ 0.18249868 -0.15642893 -0.02725079]
# model-params: ['chest_pain', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.47519055174861535
# slope: [ 0.21091675 -0.00048861 -0.09604731]
# model-params: ['chest_pain', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.4252429745223235
# slope: [-0.00323102  0.1006471   0.00896731]
# model-params: ['resting_BP', 'resting_ECG', 'max_heart_rate']
# <class 'numpy.float64'>
# intercept: 0.9860523818677998
# slope: [-0.00271887  0.09421131 -0.18286783]
# model-params: ['resting_BP', 'resting_ECG', 'caa']
# <class 'numpy.float64'>
# intercept: 1.0804886018989532
# slope: [-0.00356533  0.10909742 -0.00050459]
# model-params: ['resting_BP', 'resting_ECG', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.9759125851764519
# slope: [-0.003753    0.1163507   0.00798997]
# model-params: ['resting_BP', 'resting_ECG', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.12811745427078203
# slope: [-0.0027701   0.00766111 -0.14968786]
# model-params: ['resting_BP', 'max_heart_rate', 'caa']
# <class 'numpy.float64'>
# intercept: -0.21272813509035993
# slope: [-0.00333672  0.00905105 -0.00064154]
# model-params: ['resting_BP', 'max_heart_rate', 'cholesterol']
# <class 'numpy.float64'>
# intercept: -0.3419738713279755
# slope: [-0.0035584   0.00905713 -0.00318258]
# model-params: ['resting_BP', 'max_heart_rate', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.166228110356383
# slope: [-0.00286984 -0.18450849 -0.00044407]
# model-params: ['resting_BP', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 1.0987206376071978
# slope: [-0.00323746 -0.18851775  0.06369884]
# model-params: ['resting_BP', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.2164453841256657
# slope: [-0.0038673  -0.0006588  -0.00419769]
# model-params: ['resting_BP', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.5401073401248242
# slope: [ 0.09430892  0.0076516  -0.15105627]
# model-params: ['resting_ECG', 'max_heart_rate', 'caa']
# <class 'numpy.float64'>
# intercept: -0.7136249513781581
# slope: [ 0.10349409  0.00906596 -0.00062195]
# model-params: ['resting_ECG', 'max_heart_rate', 'cholesterol']
# <class 'numpy.float64'>
# intercept: -0.8684886729434176
# slope: [ 0.11158317  0.00906904 -0.02041171]
# model-params: ['resting_ECG', 'max_heart_rate', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.7297882582246674
# slope: [ 0.09799575 -0.18598488 -0.00041146]
# model-params: ['resting_ECG', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.619292667524259
# slope: [ 0.10642414 -0.18949891  0.04901598]
# model-params: ['resting_ECG', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.6414011350889821
# slope: [ 0.11939606 -0.00063528 -0.02320795]
# model-params: ['resting_ECG', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.35876506815210596
# slope: [ 0.00772379 -0.15215128 -0.00057477]
# model-params: ['max_heart_rate', 'caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: -0.49938432335610883
# slope: [ 0.00770782 -0.15555966  0.02659071]
# model-params: ['max_heart_rate', 'caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.6304133043950719
# slope: [ 0.00916295 -0.00077713 -0.03272533]
# model-params: ['max_heart_rate', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.8156979959664632
# slope: [-0.1908892  -0.00055823  0.03741913]
# model-params: ['caa', 'cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.5315588771892243
# slope: [-0.01403735 -0.32765711]
# model-params: ['age', 'sex']
# <class 'numpy.float64'>
# intercept: 0.9351225329426647
# slope: [-0.01079737  0.2031499 ]
# model-params: ['age', 'chest_pain']
# <class 'numpy.float64'>
# intercept: 1.476368870599826
# slope: [-0.01101834 -0.00252833]
# model-params: ['age', 'resting_BP']
# <class 'numpy.float64'>
# intercept: 1.1222956240741173
# slope: [-0.01166383  0.10676688]
# model-params: ['age', 'resting_ECG']
# <class 'numpy.float64'>
# intercept: -0.5377059303935001
# slope: [-0.00374571  0.0085929 ]
# model-params: ['age', 'max_heart_rate']
# <class 'numpy.float64'>
# intercept: 1.0503359503429561
# slope: [-0.00696908 -0.17398268]
# model-params: ['age', 'caa']
# <class 'numpy.float64'>
# intercept: 1.2850064134588681
# slope: [-0.01192638 -0.00037382]
# model-params: ['age', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 1.2176216763219383
# slope: [-0.01237751 -0.00099256]
# model-params: ['age', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.5380550558160889
# slope: [-0.27848578  0.20346715]
# model-params: ['sex', 'chest_pain']
# <class 'numpy.float64'>
# intercept: 1.3609413892745734
# slope: [-0.31053248 -0.00459067]
# model-params: ['sex', 'resting_BP']
# <class 'numpy.float64'>
# intercept: 0.6840816459794632
# slope: [-0.29316878  0.11505749]
# model-params: ['sex', 'resting_ECG']
# <class 'numpy.float64'>
# intercept: -0.599964848681233
# slope: [-0.28139727  0.00893277]
# model-params: ['sex', 'max_heart_rate']
# <class 'numpy.float64'>
# intercept: 0.8479171787484019
# slope: [-0.25469794 -0.17735942]
# model-params: ['sex', 'caa']
# <class 'numpy.float64'>
# intercept: 1.1186301252363622
# slope: [-0.33177824 -0.00141074]
# model-params: ['sex', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.7527003979533824
# slope: [-0.29998105 -0.02160318]
# model-params: ['sex', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.959419902715269
# slope: [ 0.21349198 -0.00472036]
# model-params: ['chest_pain', 'resting_BP']
# <class 'numpy.float64'>
# intercept: 0.28505038975926084
# slope: [0.20713547 0.112119  ]
# model-params: ['chest_pain', 'resting_ECG']
# <class 'numpy.float64'>
# intercept: -0.6617561564890937
# slope: [0.16370339 0.00700322]
# model-params: ['chest_pain', 'max_heart_rate']
# <class 'numpy.float64'>
# intercept: 0.48440687023759743
# slope: [ 0.18133739 -0.15795084]
# model-params: ['chest_pain', 'caa']
# <class 'numpy.float64'>
# intercept: 0.467365914233841
# slope: [ 0.20773327 -0.00050226]
# model-params: ['chest_pain', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.3532107972464641
# slope: [ 0.21285194 -0.09752202]
# model-params: ['chest_pain', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.9736502737448658
# slope: [-0.00372539  0.11600013]
# model-params: ['resting_BP', 'resting_ECG']
# <class 'numpy.float64'>
# intercept: -0.34093828796139736
# slope: [-0.00356988  0.00905714]
# model-params: ['resting_BP', 'max_heart_rate']
# <class 'numpy.float64'>
# intercept: 1.0780814046370455
# slope: [-0.00302369 -0.18582801]
# model-params: ['resting_BP', 'caa']
# <class 'numpy.float64'>
# intercept: 1.2177643173243735
# slope: [-0.00388253 -0.00065855]
# model-params: ['resting_BP', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 1.0860490701253944
# slope: [-0.00411018 -0.00334906]
# model-params: ['resting_BP', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.8723641514492748
# slope: [0.11274421 0.00907058]
# model-params: ['resting_ECG', 'max_heart_rate']
# <class 'numpy.float64'>
# intercept: 0.6262295205695277
# slope: [ 0.1039461  -0.18723494]
# model-params: ['resting_ECG', 'caa']
# <class 'numpy.float64'>
# intercept: 0.6372795087315956
# slope: [ 0.12071812 -0.00063538]
# model-params: ['resting_ECG', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.479969294596327
# slope: [ 0.12885051 -0.02326173]
# model-params: ['resting_ECG', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: -0.49775022682987435
# slope: [ 0.00771685 -0.15423855]
# model-params: ['max_heart_rate', 'caa']
# <class 'numpy.float64'>
# intercept: -0.6351843302756135
# slope: [ 0.00916724 -0.0007801 ]
# model-params: ['max_heart_rate', 'cholesterol']
# <class 'numpy.float64'>
# intercept: -0.8241559998138261
# slope: [ 0.00918023 -0.03421906]
# model-params: ['max_heart_rate', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.8197191113990852
# slope: [-0.18909407 -0.00055731]
# model-params: ['caa', 'cholesterol']
# <class 'numpy.float64'>
# intercept: 0.6797151748545139
# slope: [-0.19287003  0.03712397]
# model-params: ['caa', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 0.7513316589918078
# slope: [-0.00081692 -0.03769626]
# model-params: ['cholesterol', 'fasting_BS']
# <class 'numpy.float64'>
# intercept: 1.2177309987821667
# slope: [-0.01238223]
# model-params: ['age']
# <class 'numpy.float64'>
# intercept: 0.7499999999999999
# slope: [-0.30072464]
# model-params: ['sex']
# <class 'numpy.float64'>
# intercept: 0.34180124351055774
# slope: [0.20967312]
# model-params: ['chest_pain']
# <class 'numpy.float64'>
# intercept: 1.0871411027198674
# slope: [-0.00412225]
# model-params: ['resting_BP']
# <class 'numpy.float64'>
# intercept: 0.4758141005374646
# slope: [0.13017705]
# model-params: ['resting_ECG']
# <class 'numpy.float64'>
# intercept: -0.8299202633611606
# slope: [0.00918479]
# model-params: ['max_heart_rate']
# <class 'numpy.float64'>
# intercept: 0.6839272651269726
# slope: [-0.1910858]
# model-params: ['caa']
# <class 'numpy.float64'>
# intercept: 0.7465813023443756
# slope: [-0.00082037]
# model-params: ['cholesterol']
# <class 'numpy.float64'>
# intercept: 0.5503875968992249
# slope: [-0.03927649]
# model-params: ['fasting_BS']
# <class 'numpy.float64'>

# %%
# Plot progress of R^2 over time 
# We see decrease as params are getting lesser
sns.lineplot(x=R_Step,y=R_Values,dashes=False)
sns.set_context("paper")
;
# Out:
# ''

# %%
# Display best solution: 

print(f'Linear regression model:')
print(f'R^2-value: {VAL}')
print(f'Variables: {COMB}')
print(f'Coefficient: {COEF}')
# Out:
# Linear regression model:
# R^2-value: 0.4322661279499087
# Variables: ('age', 'sex', 'chest_pain', 'resting_BP', 'resting_ECG', 'max_heart_rate', 'caa', 'cholesterol', 'fasting_BS')
# Coefficient: [-0.00041457 -0.26295465  0.14421939 -0.00351511  0.05491344  0.00569289
#  -0.11311381 -0.00064115  0.02476755]
